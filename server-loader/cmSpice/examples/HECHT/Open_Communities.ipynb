# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets
from ipywidgets import AppLayout
import IPython.display as pyDis

from context import community_module
from community_module.community_detection.similarityCommunityDetection import SimilarityCommunityDetection
from community_module.community_detection.explainedCommunitiesDetection import ExplainedCommunitiesDetection
from community_module.visualization.gephiVisualization import GephiVisualization

from sklearn.metrics.pairwise import cosine_similarity

# %%
hecht_implicit_df = pd.read_csv('../../data/HECHT/implicit_values.csv')
hecht_implicit_df.head()
# Out:
#      userId  LQAOTMuseum1OpenBeleifsConflict  \
# 0  NR111300                              6.0
# 1  NR111352                              4.0
# 2  NR112800                              4.0
# 3  NR115421                              4.0
# 4  NR116510                              6.0
#
#    LQAOTMuseum1OpenBeleifsImportant  LQAOTMuseum1OpenBeliefTest  \
# 0                               6.0                         1.0
# 1                               5.0                         4.0
# 2                               3.0                         4.0
# 3                               4.0                         4.0
# 4                               6.0                         1.0
#
#    LQAOTMuseum1OpenCategorizePeople  LQAOTMuseum1OpenConfuse  \
# 0                               1.0                      1.0
# 1                               2.0                      2.0
# 2                               2.0                      1.0
# 3                               3.0                      3.0
# 4                               3.0                      3.0
#
#    LQAOTMuseum1OpenConsider  LQAOTMuseum1OpenDifferentContext  \
# 0                       6.0                               6.0
# 1                       5.0                               5.0
# 2                       6.0                               5.0
# 3                       6.0                               4.0
# 4                       4.0                               4.0
#
#    LQAOTMuseum1OpenHateBeliefs  LQAOTMuseum1OpenOneWay  ...  \
# 0                          1.0                     6.0  ...
# 1                          5.0                     2.0  ...
# 2                          5.0                     2.0  ...
# 3                          3.0                     3.0  ...
# 4                          6.0                     3.0  ...
#
#    LQRHMSMuseum1HistUnderstandWorld  LQRHMSMuseum1HistUnderstandWorldNeg  \
# 0                               3.0                                  3.0
# 1                               5.0                                  3.0
# 2                               5.0                                  2.0
# 3                               5.0                                  5.0
# 4                               5.0                                  2.0
#
#    LQRHMSPrepHistDifferentiate  LQRHMSPrepHistIdentity  \
# 0                          6.0                       3
# 1                          6.0                       6
# 2                          6.0                       6
# 3                          2.0                       2
# 4                          5.0                       5
#
#    LQRHMSPrepHistPatrioticValue  LQRHMSPrepHistPersonalKnowledge  \
# 0                             1                              2.0
# 1                             6                              5.0
# 2                             6                              5.0
# 3                             2                              2.0
# 4                             6                              5.0
#
#    LQRHMSPrepHistUnderstandNews  LQRHMSPrepHistUnderstandValues  \
# 0                           5.0                             1.0
# 1                           3.0                             3.0
# 2                           3.0                             2.0
# 3                           2.0                             1.0
# 4                           6.0                             4.0
#
#    LQRHMSPrepHistUnderstandWorld  LQRHMSPrepHistUnderstandWorldNeg
# 0                            4.0                               3.0
# 1                            4.0                               2.0
# 2                            5.0                               1.0
# 3                            3.0                               4.0
# 4                            6.0                               3.0
#
# [5 rows x 43 columns]

# %%
hecht_demographic = pd.read_csv('../../data/HECHT/demographic.csv')
hecht_demographic.head()
# Out:
#      userId DemographicEducationType DemographicGender  DemographicGrade  \
# 0  NR111300                       GJ                 M                11
# 1  NR111352                       GJ                 M                11
# 2  NR112800                       GJ                 M                11
# 3  NR115421                       GJ                 F                11
# 4  NR116510                       GJ                 F                11
#
#   DemographicIdentity DemographicPolitics DemographicReligous
# 0                   J                  VR                   S
# 1                   J                   R                   S
# 2                   J                   R                   S
# 3                   J                   R                   S
# 4                   J                  VR                   M

# %%
# Calcular la matriz de similitud entre usuarios con el bloque 1 de datos de usuarios (Museum-Openess)
open_cols = [x for x in hecht_implicit_df.columns.values if '1Open' in x]
clean_cols = ['userId'] + open_cols
hecht_open_df = hecht_implicit_df[clean_cols]
hecht_open_df.to_csv('../../data/HECHT/open.csv', index=False)
hecht_open_df.head()
# Out:
#      userId  LQAOTMuseum1OpenBeleifsConflict  \
# 0  NR111300                              6.0
# 1  NR111352                              4.0
# 2  NR112800                              4.0
# 3  NR115421                              4.0
# 4  NR116510                              6.0
#
#    LQAOTMuseum1OpenBeleifsImportant  LQAOTMuseum1OpenBeliefTest  \
# 0                               6.0                         1.0
# 1                               5.0                         4.0
# 2                               3.0                         4.0
# 3                               4.0                         4.0
# 4                               6.0                         1.0
#
#    LQAOTMuseum1OpenCategorizePeople  LQAOTMuseum1OpenConfuse  \
# 0                               1.0                      1.0
# 1                               2.0                      2.0
# 2                               2.0                      1.0
# 3                               3.0                      3.0
# 4                               3.0                      3.0
#
#    LQAOTMuseum1OpenConsider  LQAOTMuseum1OpenDifferentContext  \
# 0                       6.0                               6.0
# 1                       5.0                               5.0
# 2                       6.0                               5.0
# 3                       6.0                               4.0
# 4                       4.0                               4.0
#
#    LQAOTMuseum1OpenHateBeliefs  LQAOTMuseum1OpenOneWay  \
# 0                          1.0                     6.0
# 1                          5.0                     2.0
# 2                          5.0                     2.0
# 3                          3.0                     3.0
# 4                          6.0                     3.0
#
#    LQAOTMuseum1OpenOthers  LQAOTMuseum1OpenReligiousLeaders  \
# 0                     6.0                               1.0
# 1                     3.0                               1.0
# 2                     5.0                               1.0
# 3                     5.0                               4.0
# 4                     5.0                               6.0
#
#    LQAOTMuseum1OpenValuesMore  LQAOTMuseum1OpenValuesPossible
# 0                         5.0                             1.0
# 1                         5.0                             3.0
# 2                         5.0                             4.0
# 3                         4.0                             4.0
# 4                         4.0                             5.0

# %%
'''
INPUT:
    - data: dataframe con el que se van a calcular las similitudes
    - percentage: porcentaje de usuarios con respuesta común
'''
data = hecht_open_df[open_cols]
percentage = 0.7

community_detection = ExplainedCommunitiesDetection(data, SimilarityCommunityDetection, 'euclidean')
n_communities, users_communities = community_detection.search_all_communities(answer_binary=False, percentage=percentage)

# %%
# Explicamos comunidades
users_without_community = []

for c in range(n_communities):
        community_data = community_detection.get_community(c, percentage=percentage)
        
        if len(community_data['members']) > 1:
        
            print('---------------------')
            print('COMMUNITY -', community_data['name'])
            print('\t- N. Members:', len(community_data['members']))
            print('\t- Properties:')

            for k in community_data['properties'].keys():
                print('\t\t-', k, community_data['properties'][k])
        else:
            users_without_community.extend(community_data['members'])
            
            
print('---------------------')
print('N. USERS WITHOUT COMMUNITY -', len(users_without_community))
# Out:
# ---------------------
# COMMUNITY - 0
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 1.0
# 		- LQAOTMuseum1OpenDifferentContext 6.0
# 		- LQAOTMuseum1OpenOneWay 1.0
# 		- LQAOTMuseum1OpenReligiousLeaders 1.0
# ---------------------
# COMMUNITY - 1
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 6.0
# 		- LQAOTMuseum1OpenDifferentContext 4.0
# 		- LQAOTMuseum1OpenValuesMore 4.0
# ---------------------
# COMMUNITY - 2
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenCategorizePeople 5.0
# 		- LQAOTMuseum1OpenConfuse 1.0
# 		- LQAOTMuseum1OpenDifferentContext 6.0
# 		- LQAOTMuseum1OpenHateBeliefs 6.0
# 		- LQAOTMuseum1OpenOneWay 2.0
# 		- LQAOTMuseum1OpenReligiousLeaders 1.0
# ---------------------
# COMMUNITY - 3
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 5.0
# 		- LQAOTMuseum1OpenBeliefTest 5.0
# 		- LQAOTMuseum1OpenConfuse 5.0
# 		- LQAOTMuseum1OpenOthers 6.0
# ---------------------
# COMMUNITY - 4
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenConfuse 1.0
# 		- LQAOTMuseum1OpenDifferentContext 6.0
# 		- LQAOTMuseum1OpenHateBeliefs 1.0
# 		- LQAOTMuseum1OpenOneWay 1.0
# 		- LQAOTMuseum1OpenValuesMore 6.0
# ---------------------
# COMMUNITY - 5
# 	- N. Members: 10
# 	- Properties:
# 		- LQAOTMuseum1OpenBeliefTest 4.0
# ---------------------
# COMMUNITY - 6
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 6.0
# 		- LQAOTMuseum1OpenBeleifsImportant 6.0
# 		- LQAOTMuseum1OpenBeliefTest 1.0
# 		- LQAOTMuseum1OpenCategorizePeople 1.0
# 		- LQAOTMuseum1OpenConfuse 1.0
# 		- LQAOTMuseum1OpenDifferentContext 6.0
# 		- LQAOTMuseum1OpenHateBeliefs 1.0
# 		- LQAOTMuseum1OpenOthers 6.0
# 		- LQAOTMuseum1OpenValuesMore 5.0
# 		- LQAOTMuseum1OpenValuesPossible 1.0
# ---------------------
# COMMUNITY - 8
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsImportant 6.0
# 		- LQAOTMuseum1OpenBeliefTest 4.0
# 		- LQAOTMuseum1OpenConfuse 2.0
# 		- LQAOTMuseum1OpenReligiousLeaders 1.0
# 		- LQAOTMuseum1OpenValuesMore 4.0
# 		- LQAOTMuseum1OpenValuesPossible 4.0
# ---------------------
# COMMUNITY - 9
# 	- N. Members: 3
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 1.0
# 		- LQAOTMuseum1OpenHateBeliefs 4.0
# 		- LQAOTMuseum1OpenReligiousLeaders 1.0
# 		- LQAOTMuseum1OpenValuesMore 2.0
# ---------------------
# COMMUNITY - 10
# 	- N. Members: 6
# 	- Properties:
# 		- LQAOTMuseum1OpenConfuse 2.0
# 		- LQAOTMuseum1OpenDifferentContext 6.0
# ---------------------
# COMMUNITY - 12
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsImportant 6.0
# 		- LQAOTMuseum1OpenOthers 3.0
# ---------------------
# COMMUNITY - 18
# 	- N. Members: 2
# 	- Properties:
# 		- LQAOTMuseum1OpenBeleifsConflict 4.0
# 		- LQAOTMuseum1OpenBeleifsImportant 6.0
# 		- LQAOTMuseum1OpenBeliefTest 2.0
# 		- LQAOTMuseum1OpenConfuse 3.0
# 		- LQAOTMuseum1OpenOneWay 4.0
# 		- LQAOTMuseum1OpenOthers 6.0
# 		- LQAOTMuseum1OpenReligiousLeaders 1.0
# 		- LQAOTMuseum1OpenValuesPossible 4.0
# ---------------------
# COMMUNITY - 25
# 	- N. Members: 6
# 	- Properties:
# 		- LQAOTMuseum1OpenDifferentContext 4.0
# 		- LQAOTMuseum1OpenValuesMore 4.0
# ---------------------
# N. USERS WITHOUT COMMUNITY - 13

# %%
# Incluimos los datos de las comunidades
hecht_demographic['community'] = users_communities.values()
hecht_demographic.to_csv('../../data/HECHT/open_communities.csv', index=False)

# %%
# Filtramos las comunidades con menos de 2 usuarios
filter_groups = hecht_demographic.groupby(by='community').count()['userId'] < 2
groups_to_filter = filter_groups.index.values[filter_groups]
users_out = hecht_demographic[hecht_demographic['community'].isin(groups_to_filter)].index.values

# %%
users = hecht_demographic[hecht_demographic.columns.values].values
data = data[~data.index.isin(users_out)]
distances = cosine_similarity(data)

# %%
pd.DataFrame(distances).to_csv('../../data/HECHT/forces_open.csv', index=False)

# %%
# Pintamos en Gephi
gv = GephiVisualization(workspace='hecht_open')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /var/folders/w3/2gk573bs0lqdsfdmcky6vn0h0000gn/T/ipykernel_4000/367027469.py in <module>
#       1 # Pintamos en Gephi
# ----> 2 gv = GephiVisualization(workspace='hecht_open')
#
# ~/Documents/Investigacion/2021/CommunityModuleClean/community_module/visualization/gephiVisualization.py in __init__(self, hostname, port, workspace)
#       4
#       5     def __init__(self, hostname='localhost', port=8080, workspace='workspace0'):
# ----> 6         self.stream = streamer.Streamer(streamer.GephiWS(hostname=hostname, port=port, workspace=workspace))
#       7
#       8     def load_community(self, users, distances, users_properties=None):
#
# ~/.pyenv/versions/3.9.6/envs/community-model/lib/python3.9/site-packages/gephistreamer/streamer.py in __init__(self, hostname, port, workspace)
#     113         self.workspace = workspace
#     114         self.websocket = self.Client(self._generate_url())
# --> 115         self.websocket.connect()
#     116     def _generate_url(self):
#     117         return "ws://{hostname}:{port}/{workspace}?operation=updateGraph".format(hostname=self.hostname,
#
# ~/.pyenv/versions/3.9.6/envs/community-model/lib/python3.9/site-packages/ws4py/client/__init__.py in connect(self)
#     215             self._is_secure = True
#     216
# --> 217         self.sock.connect(self.bind_addr)
#     218
#     219         self._write(self.handshake_request)
#
# ConnectionRefusedError: [Errno 61] Connection refused

# %%
# Separo los datos demográficos

# %%
# Preparamos los datos de usuarios y distancias

users = hecht_demographic[hecht_demographic.columns.values].values
data = data[~data.index.isin(users_out)]
distances = cosine_similarity(data)

# %%
gv.load_community(users, distances, users_properties=list(hecht_demographic.columns.values[1:]))

# %%
list(hecht_demographic.columns.values)

# %%
hecht_demographic[hecht_demographic.columns.values].values
